# %%
#code to read the data 
import torch
import numpy as np
import pandas as pd

# %%
file = np.array([['Data/exp1_4W.csv', 'Data/exp1_5W.csv', 'Data/exp1_6W.csv'],          #what data belongs together and what do the parameter mean?
         #['data/exp2_4W.csv', 'data/exp2_5W.csv', 'data/exp2_6W.csv'],
         #['data/exp3_4W.csv', 'data/exp3_5W.csv', 'data/exp3_6W.csv'],
         #['data/T1_4W.csv', 'data/T1_5W.csv', 'data/T1_6W.csv'],
         #['data/T2_4W.csv', 'data/T2_5W.csv', 'data/T2_6W.csv'],
         #['data/T3_4W.csv', 'data/T3_5W.csv', 'data/T3_6W.csv']
         ])

data = pd.read_csv('data/'+file, sep=',')
data = data.replace(np.nan, 0.)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 9
#       1 file = np.array([['Data/exp1_4W.csv', 'Data/exp1_5W.csv', 'Data/exp1_6W.csv'],
#       2          #['data/exp2_4W.csv', 'data/exp2_5W.csv', 'data/exp2_6W.csv'],
#       3          #['data/exp3_4W.csv', 'data/exp3_5W.csv', 'data/exp3_6W.csv'],
#    (...)      6          #['data/T3_4W.csv', 'data/T3_5W.csv', 'data/T3_6W.csv']
#       7          ])
# ----> 9 data = pd.read_csv('data/'+file, sep=',')
#      10 data = data.replace(np.nan, 0.)
#
# ...
