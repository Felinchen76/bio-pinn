# %%
#code to read the data 
import torch
import numpy as np
import pandas as pd
import glob
from pathlib import Path

# %%
#files = np.array([['/workspaces/Test/data/exp1_4W.csv', '/workspaces/Test/data/exp1_5W.csv', '/workspaces/Test/data/exp1_6W.csv'],
 #        ['/workspaces/Test/data/exp2_4W.csv', '/workspaces/Test/data/exp2_5W.csv', '/workspaces/Test/data/exp2_6W.csv'],
  #       ['/workspaces/Test/data/exp3_4W.csv', '/workspaces/Test/data/exp3_5W.csv', '/workspaces/Test/data/exp3_6W.csv'],
   #      ['/workspaces/Test/data/T1_4W.csv', '/workspaces/Test/data/T1_5W.csv', '/workspaces/Test/data/T1_6W.csv'],
    #     ['/workspaces/Test/data/T2_4W.csv', '/workspaces/Test/data/T2_5W.csv', '/workspaces/Test/data/T2_6W.csv'],
     #    ['/workspaces/Test/data/T3_4W.csv', '/workspaces/Test/data/T3_5W.csv', '/workspaces/Test/data/T3_6W.csv']])
datae14=pd.read_csv('/workspaces/bio-pinn/Data/exp1_4W.csv')
datae15=pd.read_csv('/workspaces/bio-pinn/Data/exp1_5W.csv')
datae16=pd.read_csv('/workspaces/bio-pinn/Data/exp1_6W.csv')
datae24=pd.read_csv('/workspaces/bio-pinn/Data/exp2_4W.csv')
datae25=pd.read_csv('/workspaces/bio-pinn/Data/exp2_5W.csv')
datae26=pd.read_csv('/workspaces/bio-pinn/Data/exp2_6W.csv')
datae34=pd.read_csv('/workspaces/bio-pinn/Data/exp3_4W.csv')
datae35=pd.read_csv('/workspaces/bio-pinn/Data/exp3_5W.csv')
datae36=pd.read_csv('/workspaces/bio-pinn/Data/exp3_6W.csv')
datat14=pd.read_csv('/workspaces/bio-pinn/Data/T1_4W.csv')
datat15=pd.read_csv('/workspaces/bio-pinn/Data/T1_5W.csv')
datat16=pd.read_csv('/workspaces/bio-pinn/Data/T1_6W.csv')
datat24=pd.read_csv('/workspaces/bio-pinn/Data/T2_4W.csv')
datat25=pd.read_csv('/workspaces/bio-pinn/Data/T2_5W.csv')
datat26=pd.read_csv('/workspaces/bio-pinn/Data/T2_6W.csv')
datat34=pd.read_csv('/workspaces/bio-pinn/Data/T3_4W.csv')  
datat35=pd.read_csv('/workspaces/bio-pinn/Data/T3_5W.csv')  
datat36=pd.read_csv('/workspaces/bio-pinn/Data/T3_6W.csv')         
data4W = [datae14, datae24, datae34, datat14, datat24, datat34]
data5W = [datae15, datae25, datae35, datat15, datat25, datat35]
data6W = [datae16, datae26, datae36, datat16, datat26, datat36]
df4W = pd.concat(data4W, ignore_index=True)
df5W = pd.concat(data5W, ignore_index=True)
df6W = pd.concat(data6W, ignore_index=True)
print(df4W)
# Out:
#           t        TG        DG        MG   G  ME  Unnamed: 0    Q     T
# 0       0.0  0.619114  0.040005  0.000395 NaN NaN         NaN  NaN   NaN
# 1      60.0  0.298578  0.277327  0.172872 NaN NaN         NaN  NaN   NaN
# 2     120.0  0.060526  0.076128  0.062899 NaN NaN         NaN  NaN   NaN
# 3     240.0  0.050199  0.065211  0.058818 NaN NaN         NaN  NaN   NaN
# 4     360.0  0.033788  0.039725  0.037633 NaN NaN         NaN  NaN   NaN
# ...     ...       ...       ...       ...  ..  ..         ...  ...   ...
# 1811  596.0       NaN       NaN       NaN NaN NaN      4137.0  4.0  60.0
# 1812  597.0       NaN       NaN       NaN NaN NaN      4138.0  4.0  60.0
# 1813  598.0       NaN       NaN       NaN NaN NaN      4139.0  4.0  60.0
# 1814  599.0       NaN       NaN       NaN NaN NaN      4140.0  4.0  60.0
# 1815  600.0       NaN       NaN       NaN NaN NaN      4141.0  4.0  60.0
#
# [1816 rows x 9 columns]

# %%
# Out:
# [[0.00000000e+00 6.19114210e-01 4.00049370e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [6.00000000e+01 1.10655413e-01 1.37447174e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.20000000e+02 9.39130550e-02 1.16374370e-01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [2.40000000e+02 5.01986850e-02 6.52110910e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [3.60000000e+02 3.37878170e-02 3.97252080e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [6.00000000e+02 2.23324470e-02 2.57639970e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 16
#      14 t_data = C[:,0]
#      15 for ti in t_data:
# ---> 16     idx.append(np.where(t == ti)[0][0])
#      19 #find index T
#      20 idx = []
#
# NameError: name 't' is not defined
